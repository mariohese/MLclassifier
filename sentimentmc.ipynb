# %%
from preprocessor import preProcessSerie
import json
import time
import requests
import pandas as pd
    
def getSentiment(tweet, lista, counter):
    response = ""
    url = "http://api.meaningcloud.com/sentiment-2.1"
    tweet = tweet.encode('latin-1', 'ignore')
    tweet = tweet.decode(encoding='latin-1')
    tweet = tweet.encode('utf-8')

    apikeys = ['adb0e1dc1e6d7cf39d85af3f9d22d7b7', 'f14c341f5d79d1a292a9ba2addca0a99', '2773f584014b5f3183a638f71ce58e47']
    apikey = ''
    if (counter >= 18000 and counter<=37000):
        apikey = apikeys[1]
    elif counter > 37000:
        apikey = apikeys[2]
    else:
        apikey = apikeys[0]
    
    payload = "key="+apikey+"&lang=en&txt="+str(tweet,'utf-8')
    
    headers = {'content-type': 'application/x-www-form-urlencoded'}
    response = requests.request("POST", url, data=payload, headers=headers)
        
    #for key, value in response.items() :
        #print (key)
    sentiment = ""
    try:
        sentiment = response.json()['score_tag']
    except KeyError:
        sentiment = "NONE"
        
    lista.append(sentiment)
        
    response.connection.close()
    time.sleep(1)
    if counter == 0:
        print(sentiment)
    if counter == 10:
        print(sentiment)
    counter= counter + 1
    if counter % 100 == 0:
        print(counter)
    return (lista, counter)
    
def sentiments(data, y=None):
    dataproc = preProcessSerie(data)
    counter = 0
    lista = []
    for tweet in dataproc:
        lista, counter = getSentiment(tweet, lista, counter)
    return lista

# %%
isis = pd.read_csv('isisfanboy.csv')
about = pd.read_csv('aboutisis.csv')

isis = isis[:17392]
about = about[:17392]
#El máximo que puedo usar es 17392

dataframe = pd.concat([isis, about])
X = dataframe['tweets'].values

#sentimientos = sentiments(X)
# Out:
# P
# NONE
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# ...

# %%
print(len(sentimientos))
print(len(X))

print(type(sentimientos))

print(type(dataframe))


df = pd.DataFrame({'col':sentimientos})

print(len(df.columns))

#df.to_csv('sentiments.csv')
# Out:
# 34783
# 34783
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# 1

# %%
import pickle

pickle.dump(sentimientos, open( "mcsentiments.p", "wb" ) )

#Para cargarlo, luego hacer:    nombrequequeramos = pickle.load( open( "mcsentiments.p", "rb" ) )

# %%
import pickle

pickle.dump(df, open("sentimentsdf.p", "wb"))
